# %% [markdown]
# <a href="https://colab.research.google.com/github/GeorgieWasTaken/marmeladki/blob/main/Task2_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Урок: Работа с файлами
# ##📖 Теоретический минимум
#
# Текстовые файлы (.txt) - простые файлы с неструктурированным текстом
#
# CSV (Comma-Separated Values) - табличные данные с разделителями
#
# Excel (.xlsx, .xls) - электронные таблицы с расширенными возможностями
#
# JSON - структурированные данные в формате ключ-значение
#
# Бинарные файлы - изображения, PDF и другие нетекстовые форматы
#
# # 🔹 Основные операции с файлами
# Открытие/закрытие файла
#
# Чтение данных
#
# Запись данных
#
# Обработка больших файлов
#
#
# #📖 Материалы
#
# https://vkvideo.ru/video-194554202_456239677
#
# https://vkvideo.ru/video-194554202_456239682

# %% [markdown]
# # 🏆 Задания
#
# ## 1️⃣ Работа с текстовыми файлами
# **Задача:**
#  Создать текстовый файл, записать в него str данные и прочитать обратно

# %%
text = "Пример текста"

with open("example.txt", "w", encoding="utf-8") as file:
    file.write(text)

with open("example.txt", "r", encoding="utf-8") as file:
    content = file.read()

print(content)
# Out:
# Пример текста

# %% [markdown]
# ## 2️⃣ Работа с CSV файлами
#
# **Задача:**
#
# Создать CSV файл с табличными данными, записать и прочитать его

# %%
import csv

data = [
    ["name", "age"],
    ["Alice", 25],
    ["Bob", 30]
]

with open("data.csv", "w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerows(data)

with open("data.csv", "r", encoding="utf-8") as file:
    reader = csv.reader(file)

    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Alice', '25']
# ['Bob', '30']

# %% [markdown]
# ## 3️⃣  Работа с Excel файлами
# **Задача:** Создать Excel файл и прочитать данные из него
#
# Используйте библиотеку pandas
#
# ---

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["Alice", "Bob"],
    "age": [25, 30]
})

df.to_excel("data.xlsx", index=False)

result = pd.read_excel("data.xlsx")

print(result)
# Out:
#     name  age
# 0  Alice   25
# 1    Bob   30

# %% [markdown]
# ## 4️⃣  Чтение больших файлов по частям
#
#
# **Задача:** Обработать файл построчно без загрузки в память целиком
#
# Реализуйте чанки самостоятельно или воспользуйтесь chunk из pandas
#
# ---

# %%
with open("big_file.txt", "w", encoding="utf-8") as file:
    for i in range(1000):
        file.write(f"Строка {i}\n")

chunk_size = 100

with open("big_file.txt", "r", encoding="utf-8") as file:

    chunk = []

    for line in file:
        chunk.append(line.strip())

        if len(chunk) == chunk_size:
            print(chunk)
            chunk = []

    if chunk:
        print(chunk)
# Out:
# ['Строка 0', 'Строка 1', 'Строка 2', 'Строка 3', 'Строка 4', 'Строка 5', 'Строка 6', 'Строка 7', 'Строка 8', 'Строка 9', 'Строка 10', 'Строка 11', 'Строка 12', 'Строка 13', 'Строка 14', 'Строка 15', 'Строка 16', 'Строка 17', 'Строка 18', 'Строка 19', 'Строка 20', 'Строка 21', 'Строка 22', 'Строка 23', 'Строка 24', 'Строка 25', 'Строка 26', 'Строка 27', 'Строка 28', 'Строка 29', 'Строка 30', 'Строка 31', 'Строка 32', 'Строка 33', 'Строка 34', 'Строка 35', 'Строка 36', 'Строка 37', 'Строка 38', 'Строка 39', 'Строка 40', 'Строка 41', 'Строка 42', 'Строка 43', 'Строка 44', '
839', 'Строка 840', 'Строка 841', 'Строка 842', 'Строка 843', 'Строка 844', 'Строка 845', 'Строка 846', 'Строка 847', 'Строка 848', 'Строка 849', 'Строка 850', 'Строка 851', 'Строка 852', 'Строка 853', 'Строка 854', 'Строка 855', 'Строка 856', 'Строка 857', 'Строка 858', 'Строка 859', 'Строка 860', 'Строка 861', 'Строка 862', 'Строка 863', 'Строка 864', 'Строка 865', 'Строка 866', 'Строка 867', 'Строка 868', 'Строка 869', 'Строка 870', 'Строка 871', 'Строка 872', 'Строка 873', 'Строка 874', 'Строка 875', 'Строка 876', 'Строка 877', 'Строка 878', 'Строка 879', 'Строка 880', 'Строка 881', 'Строка 882', 'Строка 883', 'Строка 884', 'Строка 885', 'Строка 886', 'Строка 887', 'Строка 888', 'Строка 889', 'Строка 890', 'Строка 891', 'Строка 892', 'Строка 893', 'Строка 894', 'Строка 895', 'Строка 896', 'Строка 897', 'Строка 898', 'Строка 899']
# ['Строка 900', 'Строка 901', 'Строка 902', 'Строка 903', 'Строка 904', 'Строка 905', 'Строка 906', 'Строка 907', 'Строка 908', 'Строка 909', 'Строка 910', 'Строка 911', 'Строка 912', 'Строка 913', 'Строка 914', 'Строка 915', 'Строка 916', 'Строка 917', 'Строка 918', 'Строка 919', 'Строка 920', 'Строка 921', 'Строка 922', 'Строка 923', 'Строка 924', 'Строка 925', 'Строка 926', 'Строка 927', 'Строка 928', 'Строка 929', 'Строка 930', 'Строка 931', 'Строка 932', 'Строка 933', 'Строка 934', 'Строка 935', 'Строка 936', 'Строка 937', 'Строка 938', 'Строка 939', 'Строка 940', 'Строка 941', 'Строка 942', 'Строка 943', 'Строка 944', 'Строка 945', 'Строка 946', 'Строка 947', 'Строка 948', 'Строка 949', 'Строка 950', 'Строка 951', 'Строка 952', 'Строка 953', 'Строка 954', 'Строка 955', 'Строка 956', 'Строка 957', 'Строка 958', 'Строка 959', 'Строка 960', 'Строка 961', 'Строка 962', 'Строка 963', 'Строка 964', 'Строка 965', 'Строка 966', 'Строка 967', 'Строка 968', 'Строка 969', 'Строка 970', 'Строка 971', 'Строка 972', 'Строка 973', 'Строка 974', 'Строка 975', 'Строка 976', 'Строка 977', 'Строка 978', 'Строка 979', 'Строка 980', 'Строка 981', 'Строка 982', 'Строка 983', 'Строка 984', 'Строка 985', 'Строка 986', 'Строка 987', 'Строка 988', 'Строка 989', 'Строка 990', 'Строка 991', 'Строка 992', 'Строка 993', 'Строка 994', 'Строка 995', 'Строка 996', 'Строка 997', 'Строка 998', 'Строка 999']

# %% [markdown]
# ## 5️⃣ Чтение JPEG файла
# **Задача:**
#
# Создайте изображение 21х21 пиксель в формате JPEG
#
# Прочитайте JPEG файл в бинарном режиме и преобразуйте картинку в черно белую
#
# Выведете прочитанный файл как массив интенсивности пикселей
#
# ---

# %%
from PIL import Image
import numpy as np

image = Image.new("RGB", (21, 21), color="blue")

image.save("image.jpg", "JPEG")

with open("image.jpg", "rb") as file:
    binary_data = file.read()

print(binary_data[:50])

img = Image.open("image.jpg")

gray_img = img.convert("L")

pixel_array = np.array(gray_img)

print(pixel_array)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f'
# [[29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]
#  [29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29 29]]
